# %%
import numpy
import pandas as pd
import scipy

# %%
df = pd.read_csv('music_data.txt', header=None)
lat_lon = df[[116, 117]]
lat_lon.columns = ['Latitude', 'Longitude']
# Out:
#       Latitude  Longitude
# 0       -15.75     -47.95
# 1        14.91     -23.51
# 2        12.65      -8.00
# 3         9.03      38.74
# 4        34.03      -6.85
# 5        12.65      -8.00
# 6        12.65      -8.00
# 7        14.66     -17.41
# 8        52.50      -0.12
# 9        41.26      69.21
# 10       41.26      69.21
# 11       41.90      12.48
# 12       28.61      77.20
# 13       33.66      73.16
# 14       54.68      25.31
# 15       44.41      26.10
# 16       44.41      26.10
# 17       52.50      -0.12
# 18       44.41      26.10
# 19       44.41      26.10
# 20       44.41      26.10
# 21       44.41      26.10
# 22       44.41      26.10
# 23       44.41      26.10
# 24       44.41      26.10
# 25       44.41      26.10
# 26       36.70       3.21
# 27       36.70       3.21
# 28        9.03      38.74
# 29       39.91      32.83
# ...        ...        ...
# 1029     41.90      12.48
# 1030     41.90      12.48
# 1031     41.90      12.48
# ...
