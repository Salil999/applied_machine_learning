# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn import linear_model
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('abalone.data', 
                 header=None, 
                 names=['Sex', 'Length', 'Diameter', 'Height', 'Whole', 'Shucked', 'Viscera', 'Shell', 'Rings'])

# %% [markdown]
# #### 7.11a

# %%
result = smf.ols(formula='Rings ~ Length + Diameter + Height + Whole + Shucked + Viscera + Shell + Rings', data=df).fit()


print('Parameters: ', result.params.keys())
print('Parameters: ', result.params.values)

vals_zero = result.params
pred = vals_zero['Intercept'] + (df['Length'] * vals_zero['Length']) +  (df['Diameter'] * vals_zero['Diameter']) +  (df['Height'] * vals_zero['Height']) \
+ (df['Whole'] * vals_zero['Whole']) + (df['Shucked'] * vals_zero['Shucked']) + (df['Viscera'] * vals_zero['Viscera']) + (df['Shell'] * vals_zero['Rings']) \


plt.figure()
#plt.xscale('linear')
#plt.yscale('linear')
plt.axhline(y=0, color='r', linestyle='dotted')

plt.scatter(pred, df['Rings'] - pred) # Residual = Observed (y) - Expected (regression)
plt.title('Residuals in Original Coordinates')
plt.xlabel('Fitted Value')
plt.ylabel('Residual value')
plt.show()
# Out:
# Parameters:  Index(['Intercept', 'Length', 'Diameter', 'Height', 'Whole', 'Shucked',
#        'Viscera', 'Shell', 'Rings'],
#       dtype='object')
# Parameters:  [  2.60902411e-15  -2.53130850e-14   0.00000000e+00  -1.36557432e-14
#   -5.32907052e-15   2.75335310e-14   3.99680289e-15  -1.06581410e-14
#    1.00000000e+00]

# %% [markdown]
# #### 7.11b

# %%
for i in range(len(df[0])):
    if df[0][i] == "M":
        df[0][i] = "1"
    elif df[0][i] == "F":
        df[0][i] = "0"
    else df[0][i] == "I":
        df[0][i] = "-1"
df

# %%
result = smf.ols(formula='Rings ~ Sex + Length + Diameter + Height + Whole + Shucked + Viscera + Shell + Rings', data=df).fit()


print('Parameters: ', result.params.keys())
print('Parameters: ', result.params.values)

vals_zero = result.params
pred = vals_zero['Intercept'] + (df['Sex'] * vals_zero['Sex']) + (df['Length'] * vals_zero['Length']) +  (df['Diameter'] * vals_zero['Diameter']) +  (df['Height'] * vals_zero['Height']) \
+ (df['Whole'] * vals_zero['Whole']) + (df['Shucked'] * vals_zero['Shucked']) + (df['Viscera'] * vals_zero['Viscera']) + (df['Shell'] * vals_zero['Rings']) \


plt.figure()
#plt.xscale('linear')
#plt.yscale('linear')
plt.axhline(y=0, color='r', linestyle='dotted')

plt.scatter(pred, df['Rings'] - pred) # Residual = Observed (y) - Expected (regression)
plt.title('Residuals in Original Coordinates')
plt.xlabel('Fitted Value')
plt.ylabel('Residual value')
plt.show()

# %% [markdown]
# #### 7.11c

# %% [markdown]
# #### 7.11d

# %% [markdown]
# #### 7.11e

# %% [markdown]
# #### 7.11f

# %%
# glmnet
